# %% [markdown]
# # For all queries, I used the `LTR -- Hand Tuned` Model

# %% [markdown]
# # LCD TV

# %% [markdown]
# ## Query
# I typed `lcd tv` yielding the following query:

# %% [markdown]
# ```json
# {
#     "size": 500,
#     "sort": [
#         {
#             "_score": {
#                 "order": "desc"
#             }
#         }
#     ],
#     "query": {
#         "function_score": {
#             "query": {
#                 "bool": {
#                     "must": [],
#                     "should": [
#                         {
#                             "match": {
#                                 "name": {
#                                     "query": "lcd tv",
#                                     "fuzziness": "1",
#                                     "prefix_length": 2,
#                                     "boost": 0.01
#                                 }
#                             }
#                         },
#                         {
#                             "match_phrase": {
#                                 "name.hyphens": {
#                                     "query": "lcd tv",
#                                     "slop": 1,
#                                     "boost": 50
#                                 }
#                             }
#                         },
#                         {
#                             "multi_match": {
#                                 "query": "lcd tv",
#                                 "type": "phrase",
#                                 "slop": "6",
#                                 "minimum_should_match": "2<75%",
#                                 "fields": [
#                                     "name^10",
#                                     "name.hyphens^10",
#                                     "shortDescription^5",
#                                     "longDescription^5",
#                                     "department^0.5",
#                                     "sku",
#                                     "manufacturer",
#                                     "features",
#                                     "categoryPath"
#                                 ]
#                             }
#                         },
#                         {
#                             "terms": {
#                                 "sku": [
#                                     "lcd",
#                                     "tv"
#                                 ],
#                                 "boost": 50.0
#                             }
#                         },
#                         {
#                             "match": {
#                                 "name.hyphens": {
#                                     "query": "lcd tv",
#                                     "operator": "OR",
#                                     "minimum_should_match": "2<75%"
#                                 }
#                             }
#                         },
#                         {
#                             "query_string": {
#                                 "query": "1831054^0.310  2893174^0.419  2127443^0.091  2047641^0.145  14697713^0.002  2620821^0.002  2380127^0.000  2127461^0.000  9939562^0.001  1437844^0.001  2125233^0.003  2138389^0.001  2103531^0.001  2009148^0.000  8488638^0.000  1579129^0.000  2638205^0.002  8488647^0.000  2254075^0.000  2009281^0.001  2138282^0.001  9933082^0.000  1825196^0.000  3011283^0.000  2138103^0.001  2145032^0.000  1735079^0.000  17400778^0.001  9999154400050009^0.000  2138291^0.000  2125224^0.000  2363054^0.000  2522153^0.001  17590377^0.000  1894273^0.000  2416092^0.000  1405727^0.000  8724124^0.000  8234038^0.000  1347887^0.000  1854891^0.001  1675353^0.000  1486345^0.001  9763279^0.000  9763163^0.000  1894255^0.000  2803922^0.000  9748831^0.001  9999159400050002^0.000  2128276^0.000  2122324^0.001  2138246^0.000  2009087^0.000  2363655^0.000  1348076^0.000  17513807^0.000  2260049^0.000  9999159900050004^0.000  8836735^0.000  2122397^0.000  7979707^0.000  2731608^0.000  9759258^0.000  2137061^0.000  1275675^0.000  7005457^0.000  1825105^0.000  2808132^0.000  8262729^0.000  1825202^0.000  2877107^0.000  2047526^0.000  2137104^0.000  1068425^0.000  ",
#                                 "fields": [
#                                     "_id"
#                                 ]
#                             }
#                         }
#                     ],
#                     "filter": []
#                 }
#             },
#             "boost_mode": "multiply",
#             "score_mode": "sum",
#             "functions": [
#                 {
#                     "filter": {
#                         "exists": {
#                             "field": "salesRankShortTerm"
#                         }
#                     },
#                     "gauss": {
#                         "salesRankShortTerm": {
#                             "origin": "1.0",
#                             "scale": "100"
#                         }
#                     }
#                 },
#                 {
#                     "filter": {
#                         "exists": {
#                             "field": "salesRankMediumTerm"
#                         }
#                     },
#                     "gauss": {
#                         "salesRankMediumTerm": {
#                             "origin": "1.0",
#                             "scale": "1000"
#                         }
#                     }
#                 },
#                 {
#                     "filter": {
#                         "exists": {
#                             "field": "salesRankLongTerm"
#                         }
#                     },
#                     "gauss": {
#                         "salesRankLongTerm": {
#                             "origin": "1.0",
#                             "scale": "1000"
#                         }
#                     }
#                 },
#                 {
#                     "script_score": {
#                         "script": "0.0001"
#                     }
#                 }
#             ]
#         }
#     },
#     "highlight": {
#         "fields": {
#             "name": {},
#             "shortDescription": {},
#             "longDescription": {}
#         }
#     },
#     "aggs": {
#         "department": {
#             "terms": {
#                 "field": "department.keyword",
#                 "min_doc_count": 1
#             }
#         },
#         "missing_images": {
#             "missing": {
#                 "field": "image"
#             }
#         },
#         "regularPrice": {
#             "range": {
#                 "field": "regularPrice",
#                 "ranges": [
#                     {
#                         "key": "$",
#                         "to": 100
#                     },
#                     {
#                         "key": "$$",
#                         "from": 100,
#                         "to": 200
#                     },
#                     {
#                         "key": "$$$",
#                         "from": 200,
#                         "to": 300
#                     },
#                     {
#                         "key": "$$$$",
#                         "from": 300,
#                         "to": 400
#                     },
#                     {
#                         "key": "$$$$$",
#                         "from": 400,
#                         "to": 500
#                     },
#                     {
#                         "key": "$$$$$$",
#                         "from": 500
#                     }
#                 ]
#             },
#             "aggs": {
#                 "price_stats": {
#                     "stats": {
#                         "field": "regularPrice"
#                     }
#                 }
#             }
#         }
#     },
#     "rescore": {
#         "window_size": 500,
#         "query": {
#             "rescore_query": {
#                 "sltr": {
#                     "params": {
#                         "keywords": "lcd tv",
#                         "click_prior_query": "1831054^0.310  2893174^0.419  2127443^0.091  2047641^0.145  14697713^0.002  2620821^0.002  2380127^0.000  2127461^0.000  9939562^0.001  1437844^0.001  2125233^0.003  2138389^0.001  2103531^0.001  2009148^0.000  8488638^0.000  1579129^0.000  2638205^0.002  8488647^0.000  2254075^0.000  2009281^0.001  2138282^0.001  9933082^0.000  1825196^0.000  3011283^0.000  2138103^0.001  2145032^0.000  1735079^0.000  17400778^0.001  9999154400050009^0.000  2138291^0.000  2125224^0.000  2363054^0.000  2522153^0.001  17590377^0.000  1894273^0.000  2416092^0.000  1405727^0.000  8724124^0.000  8234038^0.000  1347887^0.000  1854891^0.001  1675353^0.000  1486345^0.001  9763279^0.000  9763163^0.000  1894255^0.000  2803922^0.000  9748831^0.001  9999159400050002^0.000  2128276^0.000  2122324^0.001  2138246^0.000  2009087^0.000  2363655^0.000  1348076^0.000  17513807^0.000  2260049^0.000  9999159900050004^0.000  8836735^0.000  2122397^0.000  7979707^0.000  2731608^0.000  9759258^0.000  2137061^0.000  1275675^0.000  7005457^0.000  1825105^0.000  2808132^0.000  8262729^0.000  1825202^0.000  2877107^0.000  2047526^0.000  2137104^0.000  1068425^0.000  "
#                     },
#                     "model": "ltr_model",
#                     "store": "week2"
#                 }
#             },
#             "score_mode": "total",
#             "query_weight": 0,
#             "rescore_query_weight": 2
#         }
#     }
# }
# ```

# %% [markdown]
# ## What I expect
# I expect when a user is searching for `lcd tv` is that they are looking for a new home television since LCDs were taking off and becoming affordable at this time.

# %% [markdown]
# ## Results
# 1. Samsung LCD Flat-Panel TV & DVD Home Theater System Package
#     * SKU: 999978700050000
#     * Relevant
#     * Not in list
# 2.  JVC - 26" Widescreen HD-Ready LCD TV w/Component Video Input - Silver
#     * SKU: 7153992
#     * Relevant
#     * Not in list
# 3.  Philips - 20" ED-Ready Flat-Panel LCD TV
#     * SKU: 7661979
#     * Relevant
#     * Not in list
# 4. Sharp - AQUOS 32" Widescreen HD-Ready Flat-Panel LCD TV
#     * SKU: 6938898
#     * Relevant
#     * Not in list
# 5. JVC - 32" Widescreen HD-Ready Flat-Panel LCD TV
#     * SKU: 7237411
#     * Relevant
#     * Not in List
# 6. Sony - 42" HD-Ready Rear-Projection LCD TV - Silver
#     * SKU: 5606702
#     * Relevant
#     * Not in list
# 7. Toshiba - 26" Widescreen HD-Ready Flat-Panel LCD TV - Silver
#     * SKU: 6341746
#     * Relevant
#     * Not in list
# 8. LG - Flatron 32" Widescreen Flat-Panel TFT-LCD Monitor/TV
#     * SKU: 7203126
#     * Relevant
#     * Not in list
# 9. Init™ - TV Stand for Plasma, LCD and DLP Projection TVs Up to 63"
#     * SKU: 7306346
#     * Not relevant
#     * Not in list
# 10. Sanus - Flat-Panel TV Wall Mount for 13" - 30" LCD TVs/Monitors
#     * SKU: 6255189
#     * Not relevant
#     * Not in list

# %% [markdown]
# ## Top most Relevant Query
# Number 1

# %% [markdown]
# # iPad

# %% [markdown]
# ## Query
# I typed `ipad` yielding the following query:

# %% [markdown]
# ```json
# {
#     "size": 500,
#     "sort": [
#         {
#             "_score": {
#                 "order": "desc"
#             }
#         }
#     ],
#     "query": {
#         "function_score": {
#             "query": {
#                 "bool": {
#                     "must": [],
#                     "should": [
#                         {
#                             "match": {
#                                 "name": {
#                                     "query": "ipad",
#                                     "fuzziness": "1",
#                                     "prefix_length": 2,
#                                     "boost": 0.01
#                                 }
#                             }
#                         },
#                         {
#                             "match_phrase": {
#                                 "name.hyphens": {
#                                     "query": "ipad",
#                                     "slop": 1,
#                                     "boost": 50
#                                 }
#                             }
#                         },
#                         {
#                             "multi_match": {
#                                 "query": "ipad",
#                                 "type": "phrase",
#                                 "slop": "6",
#                                 "minimum_should_match": "2<75%",
#                                 "fields": [
#                                     "name^10",
#                                     "name.hyphens^10",
#                                     "shortDescription^5",
#                                     "longDescription^5",
#                                     "department^0.5",
#                                     "sku",
#                                     "manufacturer",
#                                     "features",
#                                     "categoryPath"
#                                 ]
#                             }
#                         },
#                         {
#                             "terms": {
#                                 "sku": [
#                                     "ipad"
#                                 ],
#                                 "boost": 50.0
#                             }
#                         },
#                         {
#                             "match": {
#                                 "name.hyphens": {
#                                     "query": "ipad",
#                                     "operator": "OR",
#                                     "minimum_should_match": "2<75%"
#                                 }
#                             }
#                         },
#                         {
#                             "query_string": {
#                                 "query": "2842056^0.074  2475916^0.009  2343263^0.003  1945531^0.397  2091778^0.000  1945674^0.031  2970255^0.001  2330145^0.004  2339386^0.031  2339322^0.072  9924603^0.006  1945595^0.084  3598946^0.000  2573371^0.000  2047508^0.001  2769576^0.001  2884085^0.009  1232905^0.002  1853531^0.002  3143323^0.000  1918229^0.005  2352252^0.001  3086761^0.001  8771929^0.000  2512059^0.006  1248101^0.000  2205043^0.011  2330321^0.002  2947041^0.003  1918265^0.017  2809771^0.023  2343563^0.001  2874076^0.005  2678393^0.001  2658095^0.000  2884119^0.004  1535918^0.000  2095647^0.000  2836702^0.002  2475112^0.000  1517163^0.002  2769355^0.001  2387041^0.001  3070224^0.001  9225411^0.001  2817582^0.028  2903297^0.012  2340502^0.001  9809492^0.004  2883101^0.005  2633042^0.000  2012081^0.001  1207432^0.002  3038031^0.000  9755322^0.003  2339904^0.002  1286073^0.005  2731608^0.000  2035347^0.000  2197043^0.002  1151337^0.002  1218814^0.002  2538172^0.003  2506119^0.001  2012188^0.002  9443836^0.000  3047444^0.001  1946179^0.002  2341061^0.000  2122324^0.001  2343139^0.006  2954536^0.000  2390524^0.001  3301735^0.004  2969477^0.001  1230843^0.002  9889715^0.001  1450131^0.000  9225377^0.001  2971069^0.002  2658077^0.001  9635348^0.002  1918159^0.006  2861307^0.000  2840076^0.000  3245029^0.000  2141106^0.000  1854328^0.001  2629877^0.000  2804894^0.001  1510594^0.000  9947181^0.001  2340071^0.002  2794165^0.000  2145184^0.000  1198637^0.000  1526161^0.000  2408224^0.003  2629904^0.001  3061366^0.000  1446623^0.000  2091723^0.000  3021235^0.000  2319133^0.004  1485072^0.000  9499278^0.000  2490083^0.001  2643427^0.001  2340017^0.001  2684193^0.004  2577164^0.000  2663006^0.000  2107449^0.000  2343184^0.000  2670346^0.000  2319197^0.001  2634263^0.001  1946197^0.001  2954897^0.000  2817743^0.003  2840094^0.000  2339877^0.001  3016109^0.001  1259838^0.001  3478046^0.001  9491935^0.000  1114133^0.002  2340487^0.001  2318055^0.000  2660188^0.000  2731052^0.000  9832597^0.000  2677297^0.000  2125233^0.000  2730336^0.000  3386049^0.000  9999162000050000^0.001  2340557^0.002  2861158^0.000  2121725^0.000  9889014^0.000  2490065^0.000  3016127^0.001  2560082^0.000  9889724^0.000  2768901^0.000  9892921^0.000  2506173^0.000  2091796^0.000  2009227^0.000  3074132^0.000  1609376^0.002  3005219^0.000  1685043^0.000  2506094^0.000  3124037^0.000  2681202^0.001  1248271^0.000  1623912^0.000  9225439^0.000  3258679^0.000  3048064^0.000  1974715^0.000  2837365^0.001  3184308^0.000  1257136^0.000  2339986^0.000  3603215^0.000  2339659^0.000  2971078^0.000  2507472^0.000  2494413^0.000  1563656^0.000  2833778^0.000  1445624^0.000  2173056^0.000  3143456^0.000  2633112^0.000  3003963^0.000  2596814^0.000  2181067^0.000  2298157^0.000  2873165^0.000  2843161^0.000  2502034^0.000  2670433^0.000  2494671^0.000  2034199^0.000  2871825^0.001  2932378^0.000  2738738^0.001  1259055^0.000  1221963^0.000  2740208^0.000  1559547^0.000  2833814^0.000  2856614^0.000  2678499^0.000  2061077^0.000  1430805^0.000  2754104^0.000  1509877^0.000  2284337^0.000  2363655^0.000  3131356^0.000  1623867^0.000  1685061^0.000  2837383^0.000  1158093^0.000  3486949^0.000  1347887^0.000  1634257^0.000  9466295^0.000  ",
#                                 "fields": [
#                                     "_id"
#                                 ]
#                             }
#                         }
#                     ],
#                     "filter": []
#                 }
#             },
#             "boost_mode": "multiply",
#             "score_mode": "sum",
#             "functions": [
#                 {
#                     "filter": {
#                         "exists": {
#                             "field": "salesRankShortTerm"
#                         }
#                     },
#                     "gauss": {
#                         "salesRankShortTerm": {
#                             "origin": "1.0",
#                             "scale": "100"
#                         }
#                     }
#                 },
#                 {
#                     "filter": {
#                         "exists": {
#                             "field": "salesRankMediumTerm"
#                         }
#                     },
#                     "gauss": {
#                         "salesRankMediumTerm": {
#                             "origin": "1.0",
#                             "scale": "1000"
#                         }
#                     }
#                 },
#                 {
#                     "filter": {
#                         "exists": {
#                             "field": "salesRankLongTerm"
#                         }
#                     },
#                     "gauss": {
#                         "salesRankLongTerm": {
#                             "origin": "1.0",
#                             "scale": "1000"
#                         }
#                     }
#                 },
#                 {
#                     "script_score": {
#                         "script": "0.0001"
#                     }
#                 }
#             ]
#         }
#     },
#     "highlight": {
#         "fields": {
#             "name": {},
#             "shortDescription": {},
#             "longDescription": {}
#         }
#     },
#     "aggs": {
#         "department": {
#             "terms": {
#                 "field": "department.keyword",
#                 "min_doc_count": 1
#             }
#         },
#         "missing_images": {
#             "missing": {
#                 "field": "image"
#             }
#         },
#         "regularPrice": {
#             "range": {
#                 "field": "regularPrice",
#                 "ranges": [
#                     {
#                         "key": "$",
#                         "to": 100
#                     },
#                     {
#                         "key": "$$",
#                         "from": 100,
#                         "to": 200
#                     },
#                     {
#                         "key": "$$$",
#                         "from": 200,
#                         "to": 300
#                     },
#                     {
#                         "key": "$$$$",
#                         "from": 300,
#                         "to": 400
#                     },
#                     {
#                         "key": "$$$$$",
#                         "from": 400,
#                         "to": 500
#                     },
#                     {
#                         "key": "$$$$$$",
#                         "from": 500
#                     }
#                 ]
#             },
#             "aggs": {
#                 "price_stats": {
#                     "stats": {
#                         "field": "regularPrice"
#                     }
#                 }
#             }
#         }
#     },
#     "rescore": {
#         "window_size": 500,
#         "query": {
#             "rescore_query": {
#                 "sltr": {
#                     "params": {
#                         "keywords": "ipad",
#                         "click_prior_query": "2842056^0.074  2475916^0.009  2343263^0.003  1945531^0.397  2091778^0.000  1945674^0.031  2970255^0.001  2330145^0.004  2339386^0.031  2339322^0.072  9924603^0.006  1945595^0.084  3598946^0.000  2573371^0.000  2047508^0.001  2769576^0.001  2884085^0.009  1232905^0.002  1853531^0.002  3143323^0.000  1918229^0.005  2352252^0.001  3086761^0.001  8771929^0.000  2512059^0.006  1248101^0.000  2205043^0.011  2330321^0.002  2947041^0.003  1918265^0.017  2809771^0.023  2343563^0.001  2874076^0.005  2678393^0.001  2658095^0.000  2884119^0.004  1535918^0.000  2095647^0.000  2836702^0.002  2475112^0.000  1517163^0.002  2769355^0.001  2387041^0.001  3070224^0.001  9225411^0.001  2817582^0.028  2903297^0.012  2340502^0.001  9809492^0.004  2883101^0.005  2633042^0.000  2012081^0.001  1207432^0.002  3038031^0.000  9755322^0.003  2339904^0.002  1286073^0.005  2731608^0.000  2035347^0.000  2197043^0.002  1151337^0.002  1218814^0.002  2538172^0.003  2506119^0.001  2012188^0.002  9443836^0.000  3047444^0.001  1946179^0.002  2341061^0.000  2122324^0.001  2343139^0.006  2954536^0.000  2390524^0.001  3301735^0.004  2969477^0.001  1230843^0.002  9889715^0.001  1450131^0.000  9225377^0.001  2971069^0.002  2658077^0.001  9635348^0.002  1918159^0.006  2861307^0.000  2840076^0.000  3245029^0.000  2141106^0.000  1854328^0.001  2629877^0.000  2804894^0.001  1510594^0.000  9947181^0.001  2340071^0.002  2794165^0.000  2145184^0.000  1198637^0.000  1526161^0.000  2408224^0.003  2629904^0.001  3061366^0.000  1446623^0.000  2091723^0.000  3021235^0.000  2319133^0.004  1485072^0.000  9499278^0.000  2490083^0.001  2643427^0.001  2340017^0.001  2684193^0.004  2577164^0.000  2663006^0.000  2107449^0.000  2343184^0.000  2670346^0.000  2319197^0.001  2634263^0.001  1946197^0.001  2954897^0.000  2817743^0.003  2840094^0.000  2339877^0.001  3016109^0.001  1259838^0.001  3478046^0.001  9491935^0.000  1114133^0.002  2340487^0.001  2318055^0.000  2660188^0.000  2731052^0.000  9832597^0.000  2677297^0.000  2125233^0.000  2730336^0.000  3386049^0.000  9999162000050000^0.001  2340557^0.002  2861158^0.000  2121725^0.000  9889014^0.000  2490065^0.000  3016127^0.001  2560082^0.000  9889724^0.000  2768901^0.000  9892921^0.000  2506173^0.000  2091796^0.000  2009227^0.000  3074132^0.000  1609376^0.002  3005219^0.000  1685043^0.000  2506094^0.000  3124037^0.000  2681202^0.001  1248271^0.000  1623912^0.000  9225439^0.000  3258679^0.000  3048064^0.000  1974715^0.000  2837365^0.001  3184308^0.000  1257136^0.000  2339986^0.000  3603215^0.000  2339659^0.000  2971078^0.000  2507472^0.000  2494413^0.000  1563656^0.000  2833778^0.000  1445624^0.000  2173056^0.000  3143456^0.000  2633112^0.000  3003963^0.000  2596814^0.000  2181067^0.000  2298157^0.000  2873165^0.000  2843161^0.000  2502034^0.000  2670433^0.000  2494671^0.000  2034199^0.000  2871825^0.001  2932378^0.000  2738738^0.001  1259055^0.000  1221963^0.000  2740208^0.000  1559547^0.000  2833814^0.000  2856614^0.000  2678499^0.000  2061077^0.000  1430805^0.000  2754104^0.000  1509877^0.000  2284337^0.000  2363655^0.000  3131356^0.000  1623867^0.000  1685061^0.000  2837383^0.000  1158093^0.000  3486949^0.000  1347887^0.000  1634257^0.000  9466295^0.000"
#                     },
#                     "model": "ltr_model",
#                     "store": "week2"
#                 }
#             },
#             "score_mode": "total",
#             "query_weight": 0,
#             "rescore_query_weight": 2
#         }
#     }
# }
# ```

# %% [markdown]
# ## What I expect
# When querying for an ipad I would believe users are looking for iPads and potentially accessories; but, I expect they are mostly looking for iPads. It is possible to also be looking for other tablets.

# %% [markdown]
# ## Results
# 1. Rocketfish™ - Sun Shade for Apple® iPad® 2 and iPad (3rd Generation)
#     * SKU: 5560064
#     * Not Relevant
#     * Not in list
# 2. Puma - Blueprint Portfolio for Apple® iPad® 2 and iPad (3rd Generation) - Black
#     * SKU: 5263938
#     * Not Relevant
#     * Not in list
# 3. iRoom - In-Wall Docking Station for Apple® iPad® 2 and iPad (3rd Generation)
#     * SKU: 5469921
#     * Not Relevant
#     * Not in list
# 4. Apple® - iPod touch® 32GB* MP3 Player (4th Generation - Latest Model) - Black
#     * SKU: 9225411
#     * Not Relevant
#     * In list
# 5. Samsung - Galaxy Tab 2 7.0 with 8GB Memory - Titanium Silver
#     * SKU: 5064393
#     * Relevant
#     * Not in List
# 6. Rocketfish™ - Bluetooth Speaker for Apple® iPad®, iPad 2 and iPad (3rd Generation)
#     * SKU: 3640066
#     * Not relevant
#     * Not in list
# 7. Rocketfish™ Mobile - Fire 3 Earbud Headphones for Apple® iPod®, iPhone® and iPad® - White
#     * SKU: 3590413
#     * Not relevant
#     * Not in list
# 8. iRoom - In-Wall Docking Station for Apple® iPad® 2 and iPad (3rd Generation)
#     * SKU: 5469985
#     * Not relevant
#     * Not in list
# 9. Rocketfish™ - Stylus - Purple
#     * SKU: 5236529
#     * Not relevant
#     * Not in list
# 10. Apple® - iPod touch® 8GB* MP3 Player (4th Generation - Latest Model) - White
#     * SKU: 3109302
#     * Not relevant
#     * Not in list

# %% [markdown]
# ## Top Relevant Query
# Number 5 was the first tablet on my SERP. The first actual iPad didn't show up until result 31.

# %% [markdown]
# # Touchpad

# %% [markdown]
# ## Query
# I typed in `touchpad` and got the following query:

# %% [markdown]
# ```json
# {
#     "size": 500,
#     "sort": [
#         {
#             "_score": {
#                 "order": "desc"
#             }
#         }
#     ],
#     "query": {
#         "function_score": {
#             "query": {
#                 "bool": {
#                     "must": [],
#                     "should": [
#                         {
#                             "match": {
#                                 "name": {
#                                     "query": "touchpad",
#                                     "fuzziness": "1",
#                                     "prefix_length": 2,
#                                     "boost": 0.01
#                                 }
#                             }
#                         },
#                         {
#                             "match_phrase": {
#                                 "name.hyphens": {
#                                     "query": "touchpad",
#                                     "slop": 1,
#                                     "boost": 50
#                                 }
#                             }
#                         },
#                         {
#                             "multi_match": {
#                                 "query": "touchpad",
#                                 "type": "phrase",
#                                 "slop": "6",
#                                 "minimum_should_match": "2<75%",
#                                 "fields": [
#                                     "name^10",
#                                     "name.hyphens^10",
#                                     "shortDescription^5",
#                                     "longDescription^5",
#                                     "department^0.5",
#                                     "sku",
#                                     "manufacturer",
#                                     "features",
#                                     "categoryPath"
#                                 ]
#                             }
#                         },
#                         {
#                             "terms": {
#                                 "sku": [
#                                     "touchpad"
#                                 ],
#                                 "boost": 50.0
#                             }
#                         },
#                         {
#                             "match": {
#                                 "name.hyphens": {
#                                     "query": "touchpad",
#                                     "operator": "OR",
#                                     "minimum_should_match": "2<75%"
#                                 }
#                             }
#                         },
#                         {
#                             "query_string": {
#                                 "query": "2842056^0.819  2809771^0.006  2663006^0.000  2884085^0.017  8856865^0.000  2947041^0.038  2884137^0.002  2873059^0.000  2884119^0.025  3530113^0.001  2883101^0.010  2660188^0.002  2596483^0.014  2817582^0.013  2339386^0.003  2847097^0.001  1364435^0.001  2339986^0.000  2380145^0.000  3459958^0.001  3301735^0.001  2684193^0.001  1945531^0.003  2475916^0.007  2012188^0.003  8771929^0.000  2969477^0.000  2121725^0.000  1945595^0.002  2061077^0.000  2319406^0.001  1090099^0.000  2921575^0.000  2512059^0.000  1230843^0.001  2490065^0.000  9783876^0.000  2012081^0.000  3158185^0.000  3055082^0.000  1517163^0.001  2971245^0.000  2677251^0.000  9984212^0.000  2837365^0.000  2906406^0.000  1233058^0.000  3016127^0.000  2009148^0.000  1945674^0.000  1854328^0.000  2404167^0.000  2740208^0.000  9225377^0.000  3478037^0.000  2872102^0.000  1048998^0.000  2070166^0.000  2840076^0.000  2836702^0.000  3224045^0.000  1305063^0.000  2219037^0.000  7149098^0.000  1174804^0.000  2730336^0.001  3131383^0.000  2833778^0.000  2339877^0.000  2903297^0.001  3459712^0.000  1623867^0.000  1648082^0.000  9999162000050003^0.000  3103256^0.000  3021165^0.000  2125233^0.000  2817743^0.001  2833183^0.000  2701158^0.000  2762573^0.000  2414049^0.000  2538172^0.000  2339322^0.000  2260049^0.000  2750748^0.000  8359652^0.000  2209261^0.000  9307788^0.000  ",
#                                 "fields": [
#                                     "_id"
#                                 ]
#                             }
#                         }
#                     ],
#                     "filter": []
#                 }
#             },
#             "boost_mode": "multiply",
#             "score_mode": "sum",
#             "functions": [
#                 {
#                     "filter": {
#                         "exists": {
#                             "field": "salesRankShortTerm"
#                         }
#                     },
#                     "gauss": {
#                         "salesRankShortTerm": {
#                             "origin": "1.0",
#                             "scale": "100"
#                         }
#                     }
#                 },
#                 {
#                     "filter": {
#                         "exists": {
#                             "field": "salesRankMediumTerm"
#                         }
#                     },
#                     "gauss": {
#                         "salesRankMediumTerm": {
#                             "origin": "1.0",
#                             "scale": "1000"
#                         }
#                     }
#                 },
#                 {
#                     "filter": {
#                         "exists": {
#                             "field": "salesRankLongTerm"
#                         }
#                     },
#                     "gauss": {
#                         "salesRankLongTerm": {
#                             "origin": "1.0",
#                             "scale": "1000"
#                         }
#                     }
#                 },
#                 {
#                     "script_score": {
#                         "script": "0.0001"
#                     }
#                 }
#             ]
#         }
#     },
#     "highlight": {
#         "fields": {
#             "name": {},
#             "shortDescription": {},
#             "longDescription": {}
#         }
#     },
#     "aggs": {
#         "department": {
#             "terms": {
#                 "field": "department.keyword",
#                 "min_doc_count": 1
#             }
#         },
#         "missing_images": {
#             "missing": {
#                 "field": "image"
#             }
#         },
#         "regularPrice": {
#             "range": {
#                 "field": "regularPrice",
#                 "ranges": [
#                     {
#                         "key": "$",
#                         "to": 100
#                     },
#                     {
#                         "key": "$$",
#                         "from": 100,
#                         "to": 200
#                     },
#                     {
#                         "key": "$$$",
#                         "from": 200,
#                         "to": 300
#                     },
#                     {
#                         "key": "$$$$",
#                         "from": 300,
#                         "to": 400
#                     },
#                     {
#                         "key": "$$$$$",
#                         "from": 400,
#                         "to": 500
#                     },
#                     {
#                         "key": "$$$$$$",
#                         "from": 500
#                     }
#                 ]
#             },
#             "aggs": {
#                 "price_stats": {
#                     "stats": {
#                         "field": "regularPrice"
#                     }
#                 }
#             }
#         }
#     },
#     "rescore": {
#         "window_size": 500,
#         "query": {
#             "rescore_query": {
#                 "sltr": {
#                     "params": {
#                         "keywords": "touchpad",
#                         "click_prior_query": "2842056^0.819  2809771^0.006  2663006^0.000  2884085^0.017  8856865^0.000  2947041^0.038  2884137^0.002  2873059^0.000  2884119^0.025  3530113^0.001  2883101^0.010  2660188^0.002  2596483^0.014  2817582^0.013  2339386^0.003  2847097^0.001  1364435^0.001  2339986^0.000  2380145^0.000  3459958^0.001  3301735^0.001  2684193^0.001  1945531^0.003  2475916^0.007  2012188^0.003  8771929^0.000  2969477^0.000  2121725^0.000  1945595^0.002  2061077^0.000  2319406^0.001  1090099^0.000  2921575^0.000  2512059^0.000  1230843^0.001  2490065^0.000  9783876^0.000  2012081^0.000  3158185^0.000  3055082^0.000  1517163^0.001  2971245^0.000  2677251^0.000  9984212^0.000  2837365^0.000  2906406^0.000  1233058^0.000  3016127^0.000  2009148^0.000  1945674^0.000  1854328^0.000  2404167^0.000  2740208^0.000  9225377^0.000  3478037^0.000  2872102^0.000  1048998^0.000  2070166^0.000  2840076^0.000  2836702^0.000  3224045^0.000  1305063^0.000  2219037^0.000  7149098^0.000  1174804^0.000  2730336^0.001  3131383^0.000  2833778^0.000  2339877^0.000  2903297^0.001  3459712^0.000  1623867^0.000  1648082^0.000  9999162000050003^0.000  3103256^0.000  3021165^0.000  2125233^0.000  2817743^0.001  2833183^0.000  2701158^0.000  2762573^0.000  2414049^0.000  2538172^0.000  2339322^0.000  2260049^0.000  2750748^0.000  8359652^0.000  2209261^0.000  9307788^0.000  "
#                     },
#                     "model": "ltr_model",
#                     "store": "week2"
#                 }
#             },
#             "score_mode": "total",
#             "query_weight": 0,
#             "rescore_query_weight": 2
#         }
#     }
# }
# ```

# %% [markdown]
# ## What I expect
# When users search for this, I expect they are looking for external touchpads for their computers.

# %% [markdown]
# ## Results
# 1. Conair - 3/4" Ceramic Hair Straightener - Black
#     * SKU: 8409992
#     * Not Relevant
#     * Not in list
# 2. Conair - Instant Heat 3/4" Curling Iron - Black
#     * SKU: 8412265
#     * Not Relevant
#     * Not in list
# 3. Logitech - Wireless Touchpad - Black
#     * SKU: 3438568
#     * Relevant
#     * Not in list
# 4. Conair - Instant Heat 3/4" Hot Brush - Black
#     * SKU: 2595005
#     * Not Relevant
#     * Not in list
# 5. Conair - Instant Heat 1-1/2" Curling Iron - Black
#     * SKU: 8412256
#     * Not Relevant
#     * Not in List
# 6. Maytag - Touchpad Dishwasher - Black
#     * SKU: 4747251
#     * Not relevant
#     * Not in list
# 7. Maytag - Touchpad Dishwasher - White
#     * SKU: 4744842
#     * Not relevant
#     * Not in list
# 8. My Baby Girl - Nintendo DS
#     * SKU: 4680436
#     * Not relevant
#     * Not in list
# 9.  GE - Profile 24" Tall Tub Built-In Dishwasher - Stainless-Steel
#     * SKU: 9590203
#     * Not relevant
#     * Not in list
# 10.  Frigidaire - Affinity 7.0 Cu. Ft. 10-Cycle Gas Dryer - Silver
#     * SKU: 9814916
#     * Not relevant
#     * Not in list

# %% [markdown]
# ## Top Result
# Position 3 actually had a touch pad and was the only touch pad in the top 10 results

# %% [markdown]
# # Beats

# %% [markdown]
# ## Query
# I typed `Beats` and I got the following query:

# %% [markdown]
# ```json
# {
#     "size": 500,
#     "sort": [
#         {
#             "_score": {
#                 "order": "desc"
#             }
#         }
#     ],
#     "query": {
#         "function_score": {
#             "query": {
#                 "bool": {
#                     "must": [],
#                     "should": [
#                         {
#                             "match": {
#                                 "name": {
#                                     "query": "Beats",
#                                     "fuzziness": "1",
#                                     "prefix_length": 2,
#                                     "boost": 0.01
#                                 }
#                             }
#                         },
#                         {
#                             "match_phrase": {
#                                 "name.hyphens": {
#                                     "query": "Beats",
#                                     "slop": 1,
#                                     "boost": 50
#                                 }
#                             }
#                         },
#                         {
#                             "multi_match": {
#                                 "query": "Beats",
#                                 "type": "phrase",
#                                 "slop": "6",
#                                 "minimum_should_match": "2<75%",
#                                 "fields": [
#                                     "name^10",
#                                     "name.hyphens^10",
#                                     "shortDescription^5",
#                                     "longDescription^5",
#                                     "department^0.5",
#                                     "sku",
#                                     "manufacturer",
#                                     "features",
#                                     "categoryPath"
#                                 ]
#                             }
#                         },
#                         {
#                             "terms": {
#                                 "sku": [
#                                     "Beats"
#                                 ],
#                                 "boost": 50.0
#                             }
#                         },
#                         {
#                             "match": {
#                                 "name.hyphens": {
#                                     "query": "Beats",
#                                     "operator": "OR",
#                                     "minimum_should_match": "2<75%"
#                                 }
#                             }
#                         },
#                         {
#                             "query_string": {
#                                 "query": "2390703^0.037  9492426^0.150  9710711^0.029  9836432^0.054  9836718^0.164  9819884^0.023  1232474^0.072  9740784^0.019  9845581^0.040  2799036^0.018  9632217^0.044  2800033^0.011  8359028^0.000  8913606^0.059  9492408^0.056  6635974^0.002  2074648^0.056  9740775^0.008  2137168^0.000  2970255^0.000  9836627^0.017  1232483^0.023  2842056^0.000  19267075^0.002  7969905^0.004  18257069^0.000  1232447^0.033  2882087^0.001  1805687^0.003  2885202^0.000  2204211^0.003  1535293^0.005  9999159900050004^0.017  2634333^0.004  2602352^0.000  2992299^0.000  1153274^0.000  2715258^0.000  9182779^0.000  9084206^0.000  3455798^0.000  9999159900050003^0.005  9422369^0.000  1535918^0.000  9984115^0.001  2961779^0.000  5335657^0.000  9251105^0.001  2992244^0.002  1326039^0.001  9450578^0.003  1167107^0.000  2204196^0.001  3371099^0.000  9740802^0.003  2686552^0.000  2670819^0.000  2992253^0.000  9842566^0.000  9755322^0.000  8977743^0.000  1161725^0.000  8964873^0.000  2882041^0.000  9637027^0.000  9996926^0.001  2596156^0.000  9356154^0.001  9910072^0.000  2024262^0.000  1600296^0.000  1247988^0.000  1240093^0.000  2658095^0.000  1072255^0.000  9630307^0.000  9219302^0.000  1620388^0.000  9225377^0.000  9630325^0.000  8483697^0.001  1077893^0.000  7798733^0.001  2992369^0.000  2247506^0.000  2197034^0.000  2170253^0.000  2238218^0.000  6825386^0.000  9797318^0.000  2817582^0.000  3136078^0.000  1117121^0.000  2781717^0.001  2845071^0.000  7215596^0.000  9845706^0.000  2636067^0.000  8889679^0.000  3301735^0.001  2634988^0.000  9504707^0.000  1089764^0.000  1114791^0.000  9806735^0.000  1162023^0.000  2882032^0.000  9835045^0.000  3021778^0.000  3146065^0.000  1535836^0.000  9943852^0.000  1257136^0.000  8159235^0.000  ",
#                                 "fields": [
#                                     "_id"
#                                 ]
#                             }
#                         }
#                     ],
#                     "filter": []
#                 }
#             },
#             "boost_mode": "multiply",
#             "score_mode": "sum",
#             "functions": [
#                 {
#                     "filter": {
#                         "exists": {
#                             "field": "salesRankShortTerm"
#                         }
#                     },
#                     "gauss": {
#                         "salesRankShortTerm": {
#                             "origin": "1.0",
#                             "scale": "100"
#                         }
#                     }
#                 },
#                 {
#                     "filter": {
#                         "exists": {
#                             "field": "salesRankMediumTerm"
#                         }
#                     },
#                     "gauss": {
#                         "salesRankMediumTerm": {
#                             "origin": "1.0",
#                             "scale": "1000"
#                         }
#                     }
#                 },
#                 {
#                     "filter": {
#                         "exists": {
#                             "field": "salesRankLongTerm"
#                         }
#                     },
#                     "gauss": {
#                         "salesRankLongTerm": {
#                             "origin": "1.0",
#                             "scale": "1000"
#                         }
#                     }
#                 },
#                 {
#                     "script_score": {
#                         "script": "0.0001"
#                     }
#                 }
#             ]
#         }
#     },
#     "highlight": {
#         "fields": {
#             "name": {},
#             "shortDescription": {},
#             "longDescription": {}
#         }
#     },
#     "aggs": {
#         "department": {
#             "terms": {
#                 "field": "department.keyword",
#                 "min_doc_count": 1
#             }
#         },
#         "missing_images": {
#             "missing": {
#                 "field": "image"
#             }
#         },
#         "regularPrice": {
#             "range": {
#                 "field": "regularPrice",
#                 "ranges": [
#                     {
#                         "key": "$",
#                         "to": 100
#                     },
#                     {
#                         "key": "$$",
#                         "from": 100,
#                         "to": 200
#                     },
#                     {
#                         "key": "$$$",
#                         "from": 200,
#                         "to": 300
#                     },
#                     {
#                         "key": "$$$$",
#                         "from": 300,
#                         "to": 400
#                     },
#                     {
#                         "key": "$$$$$",
#                         "from": 400,
#                         "to": 500
#                     },
#                     {
#                         "key": "$$$$$$",
#                         "from": 500
#                     }
#                 ]
#             },
#             "aggs": {
#                 "price_stats": {
#                     "stats": {
#                         "field": "regularPrice"
#                     }
#                 }
#             }
#         }
#     },
#     "rescore": {
#         "window_size": 500,
#         "query": {
#             "rescore_query": {
#                 "sltr": {
#                     "params": {
#                         "keywords": "Beats",
#                         "click_prior_query": "2390703^0.037  9492426^0.150  9710711^0.029  9836432^0.054  9836718^0.164  9819884^0.023  1232474^0.072  9740784^0.019  9845581^0.040  2799036^0.018  9632217^0.044  2800033^0.011  8359028^0.000  8913606^0.059  9492408^0.056  6635974^0.002  2074648^0.056  9740775^0.008  2137168^0.000  2970255^0.000  9836627^0.017  1232483^0.023  2842056^0.000  19267075^0.002  7969905^0.004  18257069^0.000  1232447^0.033  2882087^0.001  1805687^0.003  2885202^0.000  2204211^0.003  1535293^0.005  9999159900050004^0.017  2634333^0.004  2602352^0.000  2992299^0.000  1153274^0.000  2715258^0.000  9182779^0.000  9084206^0.000  3455798^0.000  9999159900050003^0.005  9422369^0.000  1535918^0.000  9984115^0.001  2961779^0.000  5335657^0.000  9251105^0.001  2992244^0.002  1326039^0.001  9450578^0.003  1167107^0.000  2204196^0.001  3371099^0.000  9740802^0.003  2686552^0.000  2670819^0.000  2992253^0.000  9842566^0.000  9755322^0.000  8977743^0.000  1161725^0.000  8964873^0.000  2882041^0.000  9637027^0.000  9996926^0.001  2596156^0.000  9356154^0.001  9910072^0.000  2024262^0.000  1600296^0.000  1247988^0.000  1240093^0.000  2658095^0.000  1072255^0.000  9630307^0.000  9219302^0.000  1620388^0.000  9225377^0.000  9630325^0.000  8483697^0.001  1077893^0.000  7798733^0.001  2992369^0.000  2247506^0.000  2197034^0.000  2170253^0.000  2238218^0.000  6825386^0.000  9797318^0.000  2817582^0.000  3136078^0.000  1117121^0.000  2781717^0.001  2845071^0.000  7215596^0.000  9845706^0.000  2636067^0.000  8889679^0.000  3301735^0.001  2634988^0.000  9504707^0.000  1089764^0.000  1114791^0.000  9806735^0.000  1162023^0.000  2882032^0.000  9835045^0.000  3021778^0.000  3146065^0.000  1535836^0.000  9943852^0.000  1257136^0.000  8159235^0.000  "
#                     },
#                     "model": "ltr_model",
#                     "store": "week2"
#                 }
#             },
#             "score_mode": "total",
#             "query_weight": 0,
#             "rescore_query_weight": 2
#         }
#     }
# }
# ```

# %% [markdown]
# ## What I expect
# I expect most users to be searching for Beats brand headphones.

# %% [markdown]
# ## Results
# 1. Bioshock (Game Guide) - Xbox 360, Windows
#     * SKU: 8513833
#     * Not Relevant
#     * Not in list
# 2. These Beats Are... - CD
#     * SKU: 13741515
#     * Not Relevant
#     * Not in list
# 3. Latino Beats: Latin Beat - Various - CD
#     * SKU: 12774429
#     * Not Relevant
#     * Not in list
# 4. Latino Beats: Latin Beat - Various - CASSETTE
#     * SKU: 12774438
#     * Not Relevant
#     * Not in list
# 5. Dance Dance Revolution Extreme 2 Bundle - PlayStation 2
#     * SKU: 7245297
#     * Not Relevant
#     * Not in List
# 6. Serious Beats 56 - Various - CD
#     * SKU: 10291668
#     * Not relevant
#     * Not in list
# 7. 68 Beats - CD
#     * SKU: 4744842
#     * Not relevant
#     * Not in list
# 8. Back Beats - CD
#     * SKU: 3016088
#     * Not relevant
#     * Not in list
# 9. Explorimenting Beats - CD
#     * SKU: 3342449
#     * Not relevant
#     * Not in list
# 10. Jeep Beats - CASSETTE
#     * SKU: 2018569
#     * Not relevant
#     * Not in list

# %% [markdown]
# ## Top Result
# There are no relevant results in the first 10. The first set of Beats headphones doesn't appear until result 45.

# %% [markdown]
# # Questions
# 1. Where did you agree and disagree on your relevance judgements? Why?
#     * Most of my queries did not return very relevant results. The LCD TV was the only SERP that worked the way I expected.
# 2. What fraction of the results did you each return as relevant for each of the four queries?
#     * 50% returned a relevant result in the top 4. 25% if you exclude the fact that an Android tablet isn't an iPad but is still a tablet.
# 3. What were the ranks of the first relevant results?
#     * Mostly bad. 1, 5/31, 4, 45
# 4. How does the search engine’s performance compare to your expectations?
#     * It doesn't compare at all yet to what I would expect. It was still a little too literal. A simple query with no ML was better in almost 50% of these cases.
# 5. What kinds of mistakes did the search engine make? Do you know why?
#     * The mistakes the search engine made are similar to those of a dumb query, it just looked for the word in the title or description. I believe it is hard to mac
