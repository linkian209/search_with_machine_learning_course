# %% [markdown]
# # Testing Stuff

# %%
import pandas as pd

# %%
simple_better = pd.read_csv("/workspace/ltr_output/analysis/simple_better.csv")
simple_better
# Out:
#                query      sku  rank_simple type_simple  found_simple  \
# 0    Toshiba Laptops  2970255           99      simple          True
# 1    Toshiba Laptops  2971032          282      simple          True
# 2    Toshiba Laptops  2809538          309      simple          True
# 3                dlp  9345639          400      simple          True
# 4      walkie talkie  9170032           64      simple          True
# ..               ...      ...          ...         ...           ...
# 672          car dvd  7770389           81      simple          True
# 673          car dvd  1733053          297      simple          True
# 674          car dvd  1981318          313      simple          True
# 675          car dvd  9727426          335      simple          True
# 676          car dvd  2821364          445      simple          True
#
#      new_simple  score_simple  rank_ltr    type_ltr  found_ltr  new_ltr  \
# ...

# %%
exp = pd.read_csv("/workspace/ltr_output/analysis/simple_ltr_explains.csv")
exp
# Out:
#                                       query      sku      score  clause_0  \
# 0                           Toshiba Laptops  2970255  53.499935  0.088397
# 1                           Toshiba Laptops  2971032  40.004448  0.068755
# 2                           Toshiba Laptops  2809538  38.410362  0.088397
# 3                                       dlp  9345639   4.474920  4.000000
# 4                             walkie talkie  9170032   3.455131  3.000000
# ..                                      ...      ...        ...       ...
# 94  2622037 2127204 2127213 2121716 2138291  9783876   2.446722  2.000000
# 95  2622037 2127204 2127213 2121716 2138291  1049078   2.316688  2.000000
# 96  2622037 2127204 2127213 2121716 2138291  1535836   2.308158  2.000000
# 97  2622037 2127204 2127213 2121716 2138291  1989073   2.424439  2.000000
# 98  2622037 2127204 2127213 2121716 2138291  2009379   2.497182  2.000000
#
#      clause_1  clause_2  Feature 0(name_match)  Feature 1(click_prior)  \
# ...

# %% [markdown]
# # Tuning results
#
# ## Baseline
# ```
# Simple MRR is 0.299
# LTR Simple MRR is 0.290
# Hand tuned MRR is 0.401
# LTR Hand Tuned MRR is 0.421
#
# Simple p@10 is 0.101
# LTR simple p@10 is 0.100
# Hand tuned p@10 is 0.185
# LTR hand tuned p@10 is 0.189
# Simple better: 1397     LTR_Simple Better: 673  Equal: 596
# HT better: 1209 LTR_HT Better: 1039     Equal: 703
# ```
# ## Big Main, Small LTR
# ```
# Simple MRR is 0.315
# LTR Simple MRR is 0.320
# Hand tuned MRR is 0.432
# LTR Hand Tuned MRR is 0.429
#
# Simple p@10 is 0.130
# LTR simple p@10 is 0.129
# Hand tuned p@10 is 0.182
# LTR hand tuned p@10 is 0.177
# Simple better: 522      LTR_Simple Better: 411  Equal: 1402
# HT better: 970  LTR_HT Better: 485      Equal: 1151
# ```
# ## Small Main, Big LTR
# ```
# Simple MRR is 0.272
# LTR Simple MRR is 0.245
# Hand tuned MRR is 0.387
# LTR Hand Tuned MRR is 0.336
#
# Simple p@10 is 0.103
# LTR simple p@10 is 0.096
# Hand tuned p@10 is 0.161
# LTR hand tuned p@10 is 0.139
# Simple better: 1427     LTR_Simple Better: 1124 Equal: 88
# HT better: 1527 LTR_HT Better: 1156     Equal: 150
# ```
# ## No Main, Default LTR
# ```
# Simple MRR is 0.302
# LTR Simple MRR is 0.247
# Hand tuned MRR is 0.433
# LTR Hand Tuned MRR is 0.236
#
# Simple p@10 is 0.125
# LTR simple p@10 is 0.095
# Hand tuned p@10 is 0.203
# LTR hand tuned p@10 is 0.093
# Simple better: 1661     LTR_Simple Better: 1208 Equal: 25
# HT better: 1926 LTR_HT Better: 1218     Equal: 16
# ```
